# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

from dataset import *
from train_abs import *

# %% [markdown]
# # Learn the reference

# %%
n_steps = 50
n_epoch = 10
n_train = 32
n_batch = 32
alpha = 1
lr_u = 1

U_range = [0,1]
x_train, x_valid = load_MNIST(32)
dataset = 'MNIST'

train_abs(n_epoch,n_train,n_batch,alpha,lr_u,n_steps,U_range,dataset,x_train)
# Out:
# psnr 53.47611427307129
# mse 4.45221576228505e-06
# best_epoch 10
